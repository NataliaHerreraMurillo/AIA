# %% [markdown]
# # SKIN LESION SEGMENTATION

# %%
# Standard imports
import cv2
import numpy as np 
import matplotlib.pyplot as plt
import sys
# %matplotlib inline

# %%
PATH = "images/ISIC_0000000.jpg"
image = cv2.imread(PATH)

# %%
plt.imshow(image)
